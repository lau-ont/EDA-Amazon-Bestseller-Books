# %% [markdown]
# ## **Top Selling Amazon Books (2009-2019)**
#
# #### This dataset contains information about top selling books of Amazon(550 books) either belonging to fiction or non-fiction.
#
# #### FEATURES:
#
# **Name** - Name of the Book
#
# **Author** - The author of the Book
#
# **User Rating** - Amazon User Rating
#
# **Reviews** - Number of written reviews on amazon
#
# **Price** - The price of the book
#
# **Year** - The Year it ranked on the bestseller
#
# **Genre** - Whether fiction or non-fiction

# %% [markdown]
# ### 1. Importing Libraries:

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import colors 
from matplotlib.gridspec import GridSpec

# %% [markdown]
# ### 2. Loading the Dataset:

# %%
df = pd.read_csv("files/bestsellers1.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# /var/folders/q5/d6h10gfs1b33l8qy7mdmhspw0000gq/T/ipykernel_22870/4157058009.py in <module>
# ----> 1 df = pd.read_csv("files/bestsellers1.csv")
#       2 df.head()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1733                 if "b" not in mode:
#    1734                     mode += "b"
# -> 1735             self.handles = get_handle(
#    1736                 f,
#    1737                 mode,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854         if ioargs.encoding and "b" not in ioargs.mode:
#     855             # Encoding
# --> 856             handle = open(
#     857                 handle,
#     858                 ioargs.mode,
#
# PermissionError: [Errno 1] Operation not permitted: 'files/bestsellers1.csv'

# %% [markdown]
# ### 3. Analysis and Visualization

# %%
df['genre'].value_counts()
# Out:
# Non Fiction    191
# Fiction        160
# Name: genre, dtype: int64

# %%
# check average rating of each genre

df.groupby('genre')['user_rating'].mean()
# Out:
# genre
# Fiction        4.615625
# Non Fiction    4.603141
# Name: user_rating, dtype: float64

# %% [markdown]
# - With the two queries above, we see that in the bestseller list for the entire decade, there are more nonfiction books, but fiction books have higher votes.

# %% [markdown]
# #### 1. Show the relationship between the year of publication and the genre.

# %%
df_ficcion = df[(df["genre"] == "Fiction")]
ficcion = df_ficcion["year"].value_counts()

x1 = ficcion.index
y1 = ficcion.values

df_no_ficcion = df[(df["genre"] == "Non Fiction")]
no_ficcion = df_no_ficcion["year"].value_counts()

x2 = no_ficcion.index
y2 = no_ficcion.values

fig,ax = plt.subplots(2,1, figsize=(12,12))  

ax[0].bar(x1,y1, color = "C4")
ax[0].set_xlabel("Year")
ax[0].set_ylabel("# of books", fontsize=16)
ax[0].set_title("Fiction", fontsize=16)

ax[1].bar(x2,y2, color = "C8")
ax[1].set_xlabel("Year")
ax[1].set_ylabel("# of books", fontsize=16)
ax[1].set_title("Non Fiction", fontsize=16)

plt.show()

# %% [markdown]
# - In 2010, there were a large number of publications in both genres.
#
# - During the following years, until 2013, they continue to be very hemogeneous.
#
# - In 2014 we see how the non-fiction genre has a rebound, and surpasses the fiction genre in number of publications until 2019.

# %% [markdown]
# #### 2. How many books are there by each author?

# %%
fig = plt.figure(figsize=(20,10))
plt.xticks(rotation=90)
sns.countplot(data = df , x =df['author'] ,palette='viridis',order=df['author'].value_counts().index[0:50])
plt.title("Authors in Amazon Best Seller 2009-2019", fontsize=16)
plt.ylabel('# of Books')
plt.show()

# %% [markdown]
# #### 2.1 Who have been the most successful authors?

# %%
top10 = df.value_counts('author')
top10 = top10[:10,]
plt.figure(figsize=(15,10))
sns.barplot(x = top10.index, y = top10.values, alpha=0.8, palette='viridis')
plt.xticks(rotation=45)
plt.title('Top 10 Authors w. Most Books In Amazon Best Seller 2009-2019', fontsize=16)
plt.ylabel('# of Books')
plt.show();

# %% [markdown]
# #### 2.2. Show the 10 most famous authors from both the Fiction and Non Fiction genre.

# %%
best_nf_books = df.groupby(['author', 'genre']).count().unstack()['name']['Non Fiction'].sort_values(ascending=False)[:10]
best_f_books = df.groupby(['author', 'genre']).count().unstack()['name']['Fiction'].sort_values(ascending=False)[:10]

color=sns.color_palette('viridis')

sns.set_style('whitegrid')

fig,axes = plt.subplots(1,2,figsize=(12,12))
plt.subplots_adjust(wspace=0)

axes[0].invert_xaxis()
axes[0].invert_yaxis()
axes[0].yaxis.tick_left()
axes[0].grid(None)
axes[0].set_xticks(range(1,int(best_nf_books.values.max())+1))
axes[0].barh(y=best_nf_books.index,width=best_nf_books.values,height=0.5,tick_label=best_nf_books.index,color=color)
axes[0].set_yticklabels(best_nf_books.index,fontsize=12)
axes[0].set_title('Non Fiction Authors',fontdict={'size':16})

axes[1].set_xticks(range(1,int(best_f_books.values.max())+1))
axes[1].invert_yaxis()
axes[1].yaxis.tick_right()
axes[1].grid(None)
axes[1].barh(y=best_f_books.index,width=best_f_books.values,height=0.5,tick_label=best_f_books.index,color=color)
axes[1].set_yticklabels(best_f_books.index,fontsize=12)
axes[1].set_title('Fiction Authors', fontdict={'size':16})

plt.show()

# %% [markdown]
# #### 3. What books have been the best valued by users?

# %%
maxim = df[(df["user_rating"] == 4.9)]
orden_maxim = maxim.sort_values(by = "reviews", ascending = False)
orden_maxim
# Out:
#                                                   name                 author  \
# 245                          Oh, the Places You'll Go!              Dr. Seuss
# 153  Harry Potter and the Chamber of Secrets: The I...           J.K. Rowling
# 187  Jesus Calling: Enjoying Peace in His Presence ...            Sarah Young
# 476                        The Very Hungry Caterpillar             Eric Carle
# 40            Brown Bear, Brown Bear, What Do You See?        Bill Martin Jr.
# 85   Dog Man: Fetch-22: From the Creator of Captain...             Dav Pilkey
# 207  Last Week Tonight with John Oliver Presents A ...             Jill Twiss
# 157  Harry Potter and the Sorcerer's Stone: The Ill...           J.K. Rowling
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)            Jeff Kinney
# 303             Strange Planet (Strange Planet Series)         Nathan W. Pyle
# 86   Dog Man: For Whom the Ball Rolls: From the Cre...             Dav Pilkey
# 486                   The Wonderful Things You Will Be  Emily Winfield Martin
# 431                                 The Magnolia Story            Chip Gaines
# 155  Harry Potter and the Goblet of Fire: The Illus...          J. K. Rowling
# 83   Dog Man: Brawl of the Wild: From the Creator o...             Dav Pilkey
# 288  Rush Revere and the Brave Pilgrims: Time-Trave...          Rush Limbaugh
# 146  Goodnight, Goodnight Construction Site (Hardco...   Sherri Duskey Rinker
# 521                             Unfreedom of the Press          Mark R. Levin
# 151                           Hamilton: The Revolution     Lin-Manuel Miranda
# 87   Dog Man: Lord of the Fleas: From the Creator o...             Dav Pilkey
# 420               The Legend of Zelda: Hyrule Historia         Patrick Thorpe
# 81   Dog Man and Cat Kid: From the Creator of Capta...             Dav Pilkey
# 82   Dog Man: A Tale of Two Kitties: From the Creat...             Dav Pilkey
# 289  Rush Revere and the First Patriots: Time-Trave...          Rush Limbaugh
# 244                        Obama: An Intimate Portrait             Pete Souza
# 156  Harry Potter and the Prisoner of Azkaban: The ...           J.K. Rowling
# 174                       Humans of New York : Stories        Brandon Stanton
# 219                                  Little Blue Truck         Alice Schertle
#
#      user_rating  reviews  price  year        genre
# 245          4.9    21834      8  2012      Fiction
# 153          4.9    19622     30  2016      Fiction
# 187          4.9    19576      8  2011  Non Fiction
# 476          4.9    19546      5  2013      Fiction
# 40           4.9    14344      5  2017      Fiction
# 85           4.9    12619      8  2019      Fiction
# 207          4.9    11881     13  2018      Fiction
# 157          4.9    10052     22  2016      Fiction
# 545          4.9     9413      8  2019      Fiction
# 303          4.9     9382      6  2019      Fiction
# 86           4.9     9089      8  2019      Fiction
# 486          4.9     8842     10  2016      Fiction
# 431          4.9     7861      5  2016  Non Fiction
# 155          4.9     7758     18  2019      Fiction
# 83           4.9     7235      4  2018      Fiction
# 288          4.9     7150     12  2013      Fiction
# 146          4.9     7038      7  2012      Fiction
# 521          4.9     5956     11  2019  Non Fiction
# 151          4.9     5867     54  2016  Non Fiction
# 87           4.9     5470      6  2018      Fiction
# 420          4.9     5396     20  2013      Fiction
# 81           4.9     5062      6  2018      Fiction
# 82           4.9     4786      8  2017      Fiction
# 289          4.9     3836     12  2014      Fiction
# 244          4.9     3192     22  2017  Non Fiction
# 156          4.9     3146     30  2017      Fiction
# 174          4.9     2812     17  2015  Non Fiction
# 219          4.9     1884      0  2014      Fiction

# %% [markdown]
# #### 4. Show the relationship between rating and time.

# %%
fig = plt.figure(figsize=(15,10))

sns.lineplot(y=df.user_rating, x=df.year, hue=df.genre, palette=["C8", "C4"])
plt.ylabel("Ratings")
plt.xlabel("Years");

# %% [markdown]
# - Most of the books received ratings between 4.5 to 4.9, but despite a drop in 2012, the votes have been rising over the years.

# %% [markdown]
# #### 5. Show the outliers.

# %%
num = df.select_dtypes(include = np.number)

fig, axes = plt.subplots(4,1, figsize = (15,15))

for i in range(len(num.columns)):
    sns.boxplot(x=num.columns[i], data = df, ax = axes[i], palette = 'viridis')

plt.show()

# %% [markdown]
# ### 4. Conclusion

# %% [markdown]
# #### In the course of the analysis, it was established which authors have been the most successful, how many books are there by each author, which books receive the best reviews from readers. In addition, it was found that non-fiction literature is becoming more often a bestseller, but users also like fiction more.
